# %% [markdown]
# - Split train/test
# - Dummify based on EDA categoricals and drop k-1
# - Random forest
#
# - Evaluate the model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df_p = pd.read_csv('pumps.csv', index_col = 0)
df_py = pd.read_csv('pumps_y.csv', index_col = 0)

# %%
df_p.shape, df_py.shape
# Out:
# ((59400, 39), (59400, 1))

# %%
#Merging pumps_y as a new column on pumps
df_p['status_group'] = df_py['status_group']

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... water_quality quality_group      quantity  \
# id                              ...
# 69572               Lake Nyasa  ...          soft          good        enough
# 8776             Lake Victoria  ...          soft          good  insufficient
# 34310                  Pangani  ...          soft          good        enough
# 67743  Ruvuma / Southern Coast  ...          soft          good           dry
# 19728            Lake Victoria  ...          soft          good      seasonal
#
#        quantity_group                source           source_type  \
# id
# 69572          enough                spring                spring
# 8776     insufficient  rainwater harvesting  rainwater harvesting
# 34310          enough                   dam                   dam
# 67743             dry           machine dbh              borehole
# 19728        seasonal  rainwater harvesting  rainwater harvesting
#
#        source_class              waterpoint_type waterpoint_type_group  \
# id
# 69572   groundwater           communal standpipe    communal standpipe
# 8776        surface           communal standpipe    communal standpipe
# 34310       surface  communal standpipe multiple    communal standpipe
# 67743   groundwater  communal standpipe multiple    communal standpipe
# 19728       surface           communal standpipe    communal standpipe
#
#          status_group
# id
# 69572      functional
# 8776       functional
# 34310      functional
# 67743  non functional
# 19728      functional
#
# [5 rows x 40 columns]

# %%
#Do train/test split
Xtrain, Xtest, ytrain, ytest = train_test_split(df_p.loc[:,'amount_tsh':'waterpoint_type_group'], df_p.loc[:,'status_group'], test_size = 0.2, random_state = 42)

# %%
#Check the sizes
Xtrain.shape, ytrain.shape
# Out:
# ((47520, 39), (47520,))

# %%
#check the header to see if indexes match
Xtrain.head()
# Out:
#        amount_tsh date_recorded funder  gps_height installer  longitude  \
# id
# 454          50.0    2013-02-27   Dmdd        2092      DMDD  35.426020
# 510           0.0    2011-03-17   Cmsr           0      Gove  35.510074
# 14146         0.0    2011-07-10   Kkkt           0      KKKT  32.499866
# 47410         0.0    2011-04-12    NaN           0       NaN  34.060484
# 1288        300.0    2011-04-05     Ki        1023        Ki  37.032690
#
#        latitude                 wpt_name  num_private        basin  ...  \
# id                                                                  ...
# 454   -4.227446                    Narmo            0     Internal  ...
# 510   -5.724555                   Lukali            0     Internal  ...
# 14146 -9.081222                 Mahakama            0   Lake Rukwa  ...
# 47410 -8.830208  Shule Ya Msingi Chosi A            0       Rufiji  ...
# 1288  -6.040787                Kwa Mjowe            0  Wami / Ruvu  ...
#
#       payment_type water_quality  quality_group      quantity quantity_group  \
# id
# 454     per bucket          soft           good  insufficient   insufficient
# 510      never pay          soft           good        enough         enough
# 14146    never pay          soft           good        enough         enough
# 47410      monthly          soft           good  insufficient   insufficient
# 1288    on failure         salty          salty        enough         enough
#
#              source   source_type source_class     waterpoint_type  \
# id
# 454          spring        spring  groundwater  communal standpipe
# 510    shallow well  shallow well  groundwater           hand pump
# 14146  shallow well  shallow well  groundwater               other
# 47410         river    river/lake      surface  communal standpipe
# 1288   shallow well  shallow well  groundwater               other
#
#       waterpoint_type_group
# id
# 454      communal standpipe
# 510               hand pump
# 14146                 other
# 47410    communal standpipe
# 1288                  other
#
# [5 rows x 39 columns]

# %%
ytrain.head()
# Out:
# id
# 454          functional
# 510          functional
# 14146    non functional
# 47410    non functional
# 1288     non functional
# Name: status_group, dtype: object

# %%
#Merge the training data back together
df_p = pd.concat([Xtrain, ytrain], axis = 1)

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded funder  gps_height installer  longitude  \
# id
# 454          50.0    2013-02-27   Dmdd        2092      DMDD  35.426020
# 510           0.0    2011-03-17   Cmsr           0      Gove  35.510074
# 14146         0.0    2011-07-10   Kkkt           0      KKKT  32.499866
# 47410         0.0    2011-04-12    NaN           0       NaN  34.060484
# 1288        300.0    2011-04-05     Ki        1023        Ki  37.032690
#
#        latitude                 wpt_name  num_private        basin  ...  \
# id                                                                  ...
# 454   -4.227446                    Narmo            0     Internal  ...
# 510   -5.724555                   Lukali            0     Internal  ...
# 14146 -9.081222                 Mahakama            0   Lake Rukwa  ...
# 47410 -8.830208  Shule Ya Msingi Chosi A            0       Rufiji  ...
# 1288  -6.040787                Kwa Mjowe            0  Wami / Ruvu  ...
#
#       water_quality quality_group      quantity  quantity_group        source  \
# id
# 454            soft          good  insufficient    insufficient        spring
# 510            soft          good        enough          enough  shallow well
# 14146          soft          good        enough          enough  shallow well
# 47410          soft          good  insufficient    insufficient         river
# 1288          salty         salty        enough          enough  shallow well
#
#         source_type  source_class     waterpoint_type waterpoint_type_group  \
# id
# 454          spring   groundwater  communal standpipe    communal standpipe
# 510    shallow well   groundwater           hand pump             hand pump
# 14146  shallow well   groundwater               other                 other
# 47410    river/lake       surface  communal standpipe    communal standpipe
# 1288   shallow well   groundwater               other                 other
#
#          status_group
# id
# 454        functional
# 510        functional
# 14146  non functional
# 47410  non functional
# 1288   non functional
#
# [5 rows x 40 columns]

# %%
#Missing Values
#Notice when you split train/test this has changed
df_p.isnull().sum() # number of missing values
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    2876
# gps_height                   0
# installer                 2889
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 296
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            2689
# recorded_by                  0
# scheme_management         3102
# scheme_name              22523
# permit                    2439
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# status_group                 0
# dtype: int64

# %% [markdown]
# Remove scheme_name and date_recorded because scheme_name is mostly empty and date_recorded is something that cant be correlated

# %%
df_p = df_p.drop(['scheme_name', 'date_recorded'], axis=1)

# %%
df_p.head(3)
# Out:
#        amount_tsh funder  gps_height installer  longitude  latitude  wpt_name  \
# id
# 454          50.0   Dmdd        2092      DMDD  35.426020 -4.227446     Narmo
# 510           0.0   Cmsr           0      Gove  35.510074 -5.724555    Lukali
# 14146         0.0   Kkkt           0      KKKT  32.499866 -9.081222  Mahakama
#
#        num_private       basin    subvillage  ... water_quality  \
# id                                            ...
# 454              0    Internal  Bashnet Kati  ...          soft
# 510              0    Internal        Lukali  ...          soft
# 14146            0  Lake Rukwa   Chawalikozi  ...          soft
#
#        quality_group      quantity quantity_group        source   source_type  \
# id
# 454             good  insufficient   insufficient        spring        spring
# 510             good        enough         enough  shallow well  shallow well
# 14146           good        enough         enough  shallow well  shallow well
#
#       source_class     waterpoint_type waterpoint_type_group    status_group
# id
# 454    groundwater  communal standpipe    communal standpipe      functional
# 510    groundwater           hand pump             hand pump      functional
# 14146  groundwater               other                 other  non functional
#
# [3 rows x 38 columns]

# %%
#Split the dataframe into numeric and categorical

# %%
#Divide df into numeric and categorical

df_num = df_p[['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']]

# %%
#Categorical df

df_cat = df_p[['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region', 'lga', 'ward', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']]

# %%
#Check the NaNs - num
df_num.isnull().sum()
# Out:
# amount_tsh           0
# gps_height           0
# longitude            0
# latitude             0
# num_private          0
# region_code          0
# district_code        0
# population           0
# construction_year    0
# dtype: int64

# %%
df_num.shape, df_cat.shape
# Out:
# ((47520, 9), (47520, 29))

# %%
df_cat.nunique()
# Out:
# funder                    1698
# installer                 1923
# wpt_name                 30742
# basin                        9
# subvillage               17232
# region                      21
# lga                        125
# ward                      2076
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# permit                       2
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# status_group                 3
# dtype: int64

# %%
#Fill all NaNs with 'no data'
df_cat_fillna = df_cat.fillna('not available')

# %%
df_cat_fillna.head()
# Out:
#               funder      installer                 wpt_name        basin  \
# id
# 454             Dmdd           DMDD                    Narmo     Internal
# 510             Cmsr           Gove                   Lukali     Internal
# 14146           Kkkt           KKKT                 Mahakama   Lake Rukwa
# 47410  not available  not available  Shule Ya Msingi Chosi A       Rufiji
# 1288              Ki             Ki                Kwa Mjowe  Wami / Ruvu
#
#          subvillage    region      lga      ward public_meeting  \
# id
# 454    Bashnet Kati   Manyara   Babati  Bashinet           True
# 510          Lukali    Dodoma     Bahi   Lamaiti           True
# 14146   Chawalikozi     Mbeya    Mbozi  Ndalambo           True
# 47410       Shuleni     Mbeya  Mbarali   Chimala           True
# 1288       Ngholong  Morogoro   Kilosa  Chakwale           True
#
#                    recorded_by  ... water_quality quality_group      quantity  \
# id                              ...
# 454    GeoData Consultants Ltd  ...          soft          good  insufficient
# 510    GeoData Consultants Ltd  ...          soft          good        enough
# 14146  GeoData Consultants Ltd  ...          soft          good        enough
# 47410  GeoData Consultants Ltd  ...          soft          good  insufficient
# 1288   GeoData Consultants Ltd  ...         salty         salty        enough
#
#       quantity_group        source   source_type source_class  \
# id
# 454     insufficient        spring        spring  groundwater
# 510           enough  shallow well  shallow well  groundwater
# 14146         enough  shallow well  shallow well  groundwater
# 47410   insufficient         river    river/lake      surface
# 1288          enough  shallow well  shallow well  groundwater
#
#           waterpoint_type waterpoint_type_group    status_group
# id
# 454    communal standpipe    communal standpipe      functional
# 510             hand pump             hand pump      functional
# 14146               other                 other  non functional
# 47410  communal standpipe    communal standpipe  non functional
# 1288                other                 other  non functional
#
# [5 rows x 29 columns]

# %%
#Check NaNs in here
#Check the NaNs - num
df_cat_fillna.isnull().sum()
# Out:
# funder                   0
# installer                0
# wpt_name                 0
# basin                    0
# subvillage               0
# region                   0
# lga                      0
# ward                     0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# permit                   0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_type              0
# source_class             0
# waterpoint_type          0
# waterpoint_type_group    0
# status_group             0
# dtype: int64

# %%
#Dummify the target
dummy_target_var = pd.get_dummies(df_cat_fillna['status_group'])

# %%
#Check the dummy df and NORMALLY remove the redundant variable. I will not here...
dummy_target_var.head()
# Out:
#        functional  functional needs repair  non functional
# id
# 454             1                        0               0
# 510             1                        0               0
# 14146           0                        0               1
# 47410           0                        0               1
# 1288            0                        0               1

# %%
#Concat original cat df and dummified target

df_cat_fillna_dummy_target = pd.concat([df_cat_fillna, dummy_target_var], axis = 1)
df_cat_fillna_dummy_target.head(3)
# Out:
#       funder installer  wpt_name       basin    subvillage   region     lga  \
# id
# 454     Dmdd      DMDD     Narmo    Internal  Bashnet Kati  Manyara  Babati
# 510     Cmsr      Gove    Lukali    Internal        Lukali   Dodoma    Bahi
# 14146   Kkkt      KKKT  Mahakama  Lake Rukwa   Chawalikozi    Mbeya   Mbozi
#
#            ward public_meeting              recorded_by  ... quantity_group  \
# id                                                       ...
# 454    Bashinet           True  GeoData Consultants Ltd  ...   insufficient
# 510     Lamaiti           True  GeoData Consultants Ltd  ...         enough
# 14146  Ndalambo           True  GeoData Consultants Ltd  ...         enough
#
#              source   source_type source_class     waterpoint_type  \
# id
# 454          spring        spring  groundwater  communal standpipe
# 510    shallow well  shallow well  groundwater           hand pump
# 14146  shallow well  shallow well  groundwater               other
#
#       waterpoint_type_group    status_group functional  \
# id
# 454      communal standpipe      functional          1
# 510               hand pump      functional          1
# 14146                 other  non functional          0
#
#       functional needs repair non functional
# id
# 454                         0              0
# 510                         0              0
# 14146                       0              1
#
# [3 rows x 32 columns]

# %%
#Dummify everything

column_list_to_dummify = ['basin','extraction_type_class','region','public_meeting','scheme_management','permit','management_group','extraction_type_class' ,'payment_type', 'quality_group', 'quantity_group',
                               'source_class', 'waterpoint_type_group']
#Dummify everything
dummy_cat_var = pd.get_dummies(df_cat_fillna[column_list_to_dummify], drop_first = True )

# %%
#Check the shape
dummy_cat_var.shape
# Out:
# (47520, 82)

# %%
#Check the column string to make sure that everything is there
dummy_cat_var.columns
#['basin','permit', 'extraction_type_class', 'management_group', 
#                                                       'payment_type', 'quality_group', 'quantity_group', 'source_class', 
#                                                       'waterpoint_type_group']
# Out:
# Index(['basin_Lake Nyasa', 'basin_Lake Rukwa', 'basin_Lake Tanganyika',
#        'basin_Lake Victoria', 'basin_Pangani', 'basin_Rufiji',
#        'basin_Ruvuma / Southern Coast', 'basin_Wami / Ruvu',
#        'extraction_type_class_handpump', 'extraction_type_class_motorpump',
#        'extraction_type_class_other', 'extraction_type_class_rope pump',
#        'extraction_type_class_submersible',
#        'extraction_type_class_wind-powered', 'region_Dar es Salaam',
#        'region_Dodoma', 'region_Iringa', 'region_Kagera', 'region_Kigoma',
#        'region_Kilimanjaro', 'region_Lindi', 'region_Manyara', 'region_Mara',
#        'region_Mbeya', 'region_Morogoro', 'region_Mtwara', 'region_Mwanza',
#        'region_Pwani', 'region_Rukwa', 'region_Ruvuma', 'region_Shinyanga',
#        'region_Singida', 'region_Tabora', 'region_Tanga',
#        'public_meeting_True', 'public_meeting_not available',
#        'scheme_management_None', 'scheme_management_Other',
#        'scheme_management_Parastatal', 'scheme_management_Private operator',
#        'scheme_management_SWC', 'scheme_management_Trust',
#        'scheme_management_VWC', 'scheme_management_WUA',
#        'scheme_management_WUG', 'scheme_management_Water Board',
#        'scheme_management_Water authority', 'scheme_management_not available',
#        'permit_True', 'permit_not available', 'management_group_other',
#        'management_group_parastatal', 'management_group_unknown',
#        'management_group_user-group', 'extraction_type_class_handpump',
#        'extraction_type_class_motorpump', 'extraction_type_class_other',
#        'extraction_type_class_rope pump', 'extraction_type_class_submersible',
#        'extraction_type_class_wind-powered', 'payment_type_monthly',
#        'payment_type_never pay', 'payment_type_on failure',
#        'payment_type_other', 'payment_type_per bucket', 'payment_type_unknown',
#        'quality_group_fluoride', 'quality_group_good', 'quality_group_milky',
#        'quality_group_salty', 'quality_group_unknown', 'quantity_group_enough',
#        'quantity_group_insufficient', 'quantity_group_seasonal',
#        'quantity_group_unknown', 'source_class_surface',
#        'source_class_unknown', 'waterpoint_type_group_communal standpipe',
#        'waterpoint_type_group_dam', 'waterpoint_type_group_hand pump',
#        'waterpoint_type_group_improved spring', 'waterpoint_type_group_other'],
#       dtype='object')

# %%
#DO NOT merge with numerical df, just assign it to the new df
num_dumm_cat = pd.concat([df_cat_fillna_dummy_target,dummy_cat_var], axis = 1)

# %%
num_dumm_cat.head()
# Out:
#               funder      installer                 wpt_name        basin  \
# id
# 454             Dmdd           DMDD                    Narmo     Internal
# 510             Cmsr           Gove                   Lukali     Internal
# 14146           Kkkt           KKKT                 Mahakama   Lake Rukwa
# 47410  not available  not available  Shule Ya Msingi Chosi A       Rufiji
# 1288              Ki             Ki                Kwa Mjowe  Wami / Ruvu
#
#          subvillage    region      lga      ward public_meeting  \
# id
# 454    Bashnet Kati   Manyara   Babati  Bashinet           True
# 510          Lukali    Dodoma     Bahi   Lamaiti           True
# 14146   Chawalikozi     Mbeya    Mbozi  Ndalambo           True
# 47410       Shuleni     Mbeya  Mbarali   Chimala           True
# 1288       Ngholong  Morogoro   Kilosa  Chakwale           True
#
#                    recorded_by  ... quantity_group_insufficient  \
# id                              ...
# 454    GeoData Consultants Ltd  ...                           1
# 510    GeoData Consultants Ltd  ...                           0
# 14146  GeoData Consultants Ltd  ...                           0
# 47410  GeoData Consultants Ltd  ...                           1
# 1288   GeoData Consultants Ltd  ...                           0
#
#       quantity_group_seasonal quantity_group_unknown source_class_surface  \
# id
# 454                         0                      0                    0
# 510                         0                      0                    0
# 14146                       0                      0                    0
# 47410                       0                      0                    1
# 1288                        0                      0                    0
#
#       source_class_unknown waterpoint_type_group_communal standpipe  \
# id
# 454                      0                                        1
# 510                      0                                        0
# 14146                    0                                        0
# 47410                    0                                        1
# 1288                     0                                        0
#
#       waterpoint_type_group_dam waterpoint_type_group_hand pump  \
# id
# 454                           0                               0
# 510                           0                               1
# 14146                         0                               0
# 47410                         0                               0
# 1288                          0                               0
#
#       waterpoint_type_group_improved spring waterpoint_type_group_other
# id
# 454                                       0                           0
# 510                                       0                           0
# 14146                                     0                           1
# 47410                                     0                           0
# 1288                                      0                           1
#
# [5 rows x 114 columns]

# %%
print(num_dumm_cat.columns)
# Out:
# Index(['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region',
#        'lga', 'ward', 'public_meeting', 'recorded_by',
#        ...
#        'quantity_group_insufficient', 'quantity_group_seasonal',
#        'quantity_group_unknown', 'source_class_surface',
#        'source_class_unknown', 'waterpoint_type_group_communal standpipe',
#        'waterpoint_type_group_dam', 'waterpoint_type_group_hand pump',
#        'waterpoint_type_group_improved spring', 'waterpoint_type_group_other'],
#       dtype='object', length=114)

# %%
# List comprehension for picking training data sets


#column_list_to_dummify = ['basin','extraction_type_class','region','public_meeting','scheme_management','permit','management_group','extraction_type_class' ,'payment_type', 'quality_group', 'quantity_group',
#                               'source_class', 'waterpoint_type_group']

#num_list =['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private', 
 #          'region_code', 'district_code', 'population', 'construction_year']

#for functionals
#s_func = '_func'
#s_nonfunc = '_nonfunc'
#s_nr = '_nr'
#func_list = [x + s_func for x in column_list_to_dummify]
#nonfunc_list = [x + s_nonfunc for x in column_list_to_dummify]
#repair_list = [x + s_nr for x in column_list_to_dummify]
#func_list.extend(num_list)
#nonfunc_list.extend(num_list)
#repair_list.extend(num_list)
#print(func_list, nonfunc_list)

# %%
print(num_dumm_cat.columns)
# Out:
# Index(['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region',
#        'lga', 'ward', 'public_meeting', 'recorded_by',
#        ...
#        'quantity_group_insufficient', 'quantity_group_seasonal',
#        'quantity_group_unknown', 'source_class_surface',
#        'source_class_unknown', 'waterpoint_type_group_communal standpipe',
#        'waterpoint_type_group_dam', 'waterpoint_type_group_hand pump',
#        'waterpoint_type_group_improved spring', 'waterpoint_type_group_other'],
#       dtype='object', length=114)

# %%
#Define data and train sets
X = num_dumm_cat.loc[:,'basin_Lake Nyasa':'waterpoint_type_group_other']
y_func = num_dumm_cat.loc[:, 'functional']
y_nonfunc = num_dumm_cat.loc[:, 'non functional']
y_repair = num_dumm_cat.loc[:, 'functional needs repair']

# %%
#Check shapes
X.shape, y_func.shape
# Out:
# ((47520, 82), (47520,))

# %%
m_f = LogisticRegression(C=1e5, solver = 'lbfgs', max_iter = 1000) # C is a hyperparameter (regularization, W03)
m_nf = LogisticRegression(C=1e5, solver = 'lbfgs', max_iter = 1000) # C is a hyperparameter (regularization, W03)
m_r = LogisticRegression(C=1e5, solver = 'lbfgs', max_iter = 1000) # C is a hyperparameter (regularization, W03)

m_f.fit(X, y_func) # find the best model parameters for this data functional pumps
m_nf.fit(X, y_nonfunc) # best model params for non_functional
m_r.fit(X, y_repair) # best model params for repair needing pumps
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=1000,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='lbfgs', tol=0.0001, verbose=0, warm_start=False)

# %%
print('Score for functional pump prediction is', m_f.score(X,y_func)) # calculates the accuracy (% of correct points) for non_func
print('Score for functional but repair needing pump prediction is', m_r.score(X,y_repair))
print('Score for nonfunctional pump prediction is', m_nf.score(X,y_nonfunc))
# Out:
# Score for functional pump prediction is 0.735479797979798
# Score for functional but repair needing pump prediction is 0.9269991582491582
# Score for nonfunctional pump prediction is 0.7835648148148148

# %%
from sklearn.model_selection import cross_val_score

#model = svm.SVC(kernel='linear', C=1.0, probability=True)

accuracy = cross_val_score(m_nf, X, y_nonfunc, cv=10, scoring='accuracy')
print("cross-validation scores", accuracy)
# Out:
# cross-validation scores [0.77677256 0.79150011 0.78935185 0.77546296 0.78156566 0.78893098
#  0.78156566 0.78177609 0.77478426 0.78509787]
