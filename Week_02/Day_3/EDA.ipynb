# %%
import pandas as pd
import seaborn as sns

# %%
df_p = pd.read_csv('pumps.csv', index_col = 0)

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... payment_type water_quality  quality_group  \
# id                              ...
# ...

# %%
#Check the shape
df_p.shape
# Out:
# (59400, 39)

# %%
#Check the descriptive stats
df_p.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# ...

# %%
sns.heatmap(df_p.corr())

# %%
df_py = pd.read_csv('pumps_y.csv', index_col = 0)

# %%
df_py.head()
# Out:
#          status_group
# id
# 69572      functional
# 8776       functional
# 34310      functional
# 67743  non functional
# 19728      functional

# %%
df_p['status_group'] = df_py['status_group']

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... water_quality quality_group      quantity  \
# id                              ...
# ...

# %%
#For numerical columns use mean
#For cat-cat use counts

def pl_cat(interest, variable):
    df_dummy = df_p.reset_index()
    gr = df_dummy.groupby([f'{interest}', f'{variable}']).count()
    br = gr.unstack(1)
    br.plot.bar(y = 'id')

# %%
pl_cat('construction_year', 'status_group')

# %%
#Categorical Exploration
#Categorical df

df_cat = df_p[['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region', 'lga', 'ward', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']]

# %%
#Unique and null
vunq = pd.concat([df_cat.nunique(), df_cat.isnull().sum()], axis = 1)
vunq
# Out:
#                            0     1
# funder                  1897  3635
# installer               2145  3655
# wpt_name               37400     0
# basin                      9     0
# subvillage             19287   371
# region                    21     0
# lga                      125     0
# ward                    2092     0
# public_meeting             2  3334
# recorded_by                1     0
# scheme_management         12  3877
# permit                     2  3056
# extraction_type           18     0
# extraction_type_group     13     0
# extraction_type_class      7     0
# management                12     0
# management_group           5     0
# payment                    7     0
# payment_type               7     0
# water_quality              8     0
# quality_group              6     0
# quantity                   5     0
# quantity_group             5     0
# source                    10     0
# source_type                7     0
# source_class               3     0
# ...

# %% [markdown]
# EDA for picked stuff

# %%
pl_cat('quantity', 'status_group') # Take

# %%
pl_cat('waterpoint_type', 'status_group') # Take

# %%
pl_cat('extraction_type', 'status_group')

# %%
pl_cat('payment', 'status_group') # Take

# %%
pl_cat('permit', 'status_group') # DO NOT Take

# %%
pl_cat('extraction_type', 'status_group') 
pl_cat('extraction_type_group', 'status_group') 
pl_cat('extraction_type_class', 'status_group') # Take

# %%
pl_cat('management', 'status_group') 
pl_cat('management_group', 'status_group') #Take

# %% [markdown]
# ## Check the numeric column dependencies ##

# %%
df_p.corr()
# Out:
#                    amount_tsh  gps_height  longitude  latitude  num_private  \
# amount_tsh           1.000000    0.076650   0.022134 -0.052670     0.002944
# gps_height           0.076650    1.000000   0.149155 -0.035751     0.007237
# longitude            0.022134    0.149155   1.000000 -0.425802     0.023873
# latitude            -0.052670   -0.035751  -0.425802  1.000000     0.006837
# num_private          0.002944    0.007237   0.023873  0.006837     1.000000
# region_code         -0.026813   -0.183521   0.034197 -0.221018    -0.020377
# district_code       -0.023599   -0.171233   0.151398 -0.201020    -0.004478
# population           0.016288    0.135003   0.086590 -0.022152     0.003818
# construction_year    0.067915    0.658727   0.396732 -0.245278     0.026056
#
#                    region_code  district_code  population  construction_year
# amount_tsh           -0.026813      -0.023599    0.016288           0.067915
# ...

# %%
list_of_num_cols = ['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private', 'region_code', 
                   'district_code', 'population', 'construction_year']

# %%
#Check the unique vals
#df_p[list_of_num_cols].nunique()
df_p[list_of_num_cols].isnull().sum()

#This shows nothing are zero but a visual inspection will!
# Out:
# amount_tsh           0
# gps_height           0
# longitude            0
# latitude             0
# num_private          0
# region_code          0
# district_code        0
# population           0
# construction_year    0
# dtype: int64

# %%
pl_cat('amount_tsh', 'status_group')

# %%
pl_cat('num_private', 'status_group')

# %%
pl_cat('region_code', 'status_group')

# %%
pl_cat('district_code', 'status_group')

# %%
#pl_cat('population', 'status_group')
df_p['population'].median()
# Out:
# 25.0

# %%
#pl_cat('construction_year', 'status_group')
df_p['construction_year'].median()
# Out:
# 1986.0

# %%
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... water_quality quality_group      quantity  \
# id                              ...
# ...

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... water_quality quality_group      quantity  \
# id                              ...
# ...

# %%
df_p.corr()
# Out:
#                    amount_tsh  gps_height  longitude  latitude  num_private  \
# amount_tsh           1.000000    0.076650   0.022134 -0.052670     0.002944
# gps_height           0.076650    1.000000   0.149155 -0.035751     0.007237
# longitude            0.022134    0.149155   1.000000 -0.425802     0.023873
# latitude            -0.052670   -0.035751  -0.425802  1.000000     0.006837
# num_private          0.002944    0.007237   0.023873  0.006837     1.000000
# region_code         -0.026813   -0.183521   0.034197 -0.221018    -0.020377
# district_code       -0.023599   -0.171233   0.151398 -0.201020    -0.004478
# population           0.016288    0.135003   0.086590 -0.022152     0.003818
# construction_year    0.067915    0.658727   0.396732 -0.245278     0.026056
#
#                    region_code  district_code  population  construction_year
# amount_tsh           -0.026813      -0.023599    0.016288           0.067915
# ...

# %%
status_dict = {'functional': 1, 'non functional': 0, 'functional needs repair' : 2}

# %%
df_p['status_cat'] = df_p['status_group'].map(status_dict)

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... quality_group      quantity  \
# id                              ...
# ...

# %%
df_p['source'].unique()
# Out:
# array(['spring', 'rainwater harvesting', 'dam', 'machine dbh', 'other',
#        'shallow well', 'river', 'hand dtw', 'lake', 'unknown'],
#       dtype=object)

# %%
df_p['source_type'].unique()
# Out:
# array(['spring', 'rainwater harvesting', 'dam', 'borehole', 'other',
#        'shallow well', 'river/lake'], dtype=object)

# %%
df_p['quality_group'].unique()
# Out:
# array(['good', 'salty', 'milky', 'unknown', 'fluoride', 'colored'],
#       dtype=object)

# %%
#Filter the data frame with the source_type
df_p.reset_index()
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0    2011-03-14                     Roman        1390
# 1       8776         0.0    2013-03-06                   Grumeti        1399
# 2      34310        25.0    2013-02-25              Lottery Club         686
# 3      67743         0.0    2013-01-28                    Unicef         263
# 4      19728         0.0    2011-07-13               Action In A           0
# 5       9944        20.0    2011-03-13       Mkinga Distric Coun           0
# 6      19816         0.0    2012-10-01                      Dwsp           0
# 7      54551         0.0    2012-10-09                     Rwssp           0
# 8      53934         0.0    2012-11-03                  Wateraid           0
# 9      46144         0.0    2011-08-03               Isingiro Ho           0
# 10     49056         0.0    2011-02-20                   Private          62
# ...

# %%
df_p.head()
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
# 67743         0.0    2013-01-28        Unicef         263        UNICEF
# 19728         0.0    2011-07-13   Action In A           0       Artisan
#
#        longitude   latitude              wpt_name  num_private  \
# id
# 69572  34.938093  -9.856322                  none            0
# 8776   34.698766  -2.147466              Zahanati            0
# 34310  37.460664  -3.821329           Kwa Mahundi            0
# 67743  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728  31.130847  -1.825359               Shuleni            0
#
#                          basin  ... quality_group      quantity  \
# id                              ...
# ...

# %%
import matplotlib.pyplot as plt
df_p.plot.scatter('longitude', 'latitude', c = df_p['status_cat'], xlim = (28,40), ylim = (-12,-1))
# it is all around the country

# %%
df_p.head(3)
# Out:
#        amount_tsh date_recorded        funder  gps_height     installer  \
# id
# 69572      6000.0    2011-03-14         Roman        1390         Roman
# 8776          0.0    2013-03-06       Grumeti        1399       GRUMETI
# 34310        25.0    2013-02-25  Lottery Club         686  World vision
#
#        longitude  latitude     wpt_name  num_private          basin  ...  \
# id                                                                   ...
# 69572  34.938093 -9.856322         none            0     Lake Nyasa  ...
# 8776   34.698766 -2.147466     Zahanati            0  Lake Victoria  ...
# 34310  37.460664 -3.821329  Kwa Mahundi            0        Pangani  ...
#
#       quality_group      quantity  quantity_group                source  \
# id
# 69572          good        enough          enough                spring
# 8776           good  insufficient    insufficient  rainwater harvesting
# 34310          good        enough          enough                   dam
#
# ...

# %%
df_p.columns
# Out:
# Index(['amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer',
#        'longitude', 'latitude', 'wpt_name', 'num_private', 'basin',
#        'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward',
#        'population', 'public_meeting', 'recorded_by', 'scheme_management',
#        'scheme_name', 'permit', 'construction_year', 'extraction_type',
#        'extraction_type_group', 'extraction_type_class', 'management',
#        'management_group', 'payment', 'payment_type', 'water_quality',
#        'quality_group', 'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group',
#        'status_group', 'status_cat'],
#       dtype='object')

# %%
df_p['installer'].unique()
# Out:
# array(['Roman', 'GRUMETI', 'World vision', ..., 'Dina', 'brown',
#        'SELEPTA'], dtype=object)

# %%
df_p.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year  \
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# ...

# %%
df_p.isnull().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# ...

# %%
#Divide df into numeric and categorical

df_numeric = df_p[['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private', 'region_code', 'district_code', 'population', 'construction_year']]

# %%
df_numeric.head()
# Out:
#        amount_tsh  gps_height  longitude   latitude  num_private  region_code  \
# id
# 69572      6000.0        1390  34.938093  -9.856322            0           11
# 8776          0.0        1399  34.698766  -2.147466            0           20
# 34310        25.0         686  37.460664  -3.821329            0           21
# 67743         0.0         263  38.486161 -11.155298            0           90
# 19728         0.0           0  31.130847  -1.825359            0           18
#
#        district_code  population  construction_year
# id
# 69572              5         109               1999
# 8776               2         280               2010
# 34310              4         250               2009
# 67743             63          58               1986
# 19728              1           0                  0

# %%
#Categorical df

df_categorical = df_p[['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region', 'lga', 'ward', 'public_meeting', 'recorded_by', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']]

# %%
df_categorical.head(3)
# Out:
#              funder     installer     wpt_name          basin subvillage  \
# id
# 69572         Roman         Roman         none     Lake Nyasa   Mnyusi B
# 8776        Grumeti       GRUMETI     Zahanati  Lake Victoria    Nyamara
# 34310  Lottery Club  World vision  Kwa Mahundi        Pangani    Majengo
#
#         region        lga      ward public_meeting              recorded_by  \
# id
# 69572   Iringa     Ludewa  Mundindi           True  GeoData Consultants Ltd
# 8776      Mara  Serengeti     Natta            NaN  GeoData Consultants Ltd
# 34310  Manyara  Simanjiro   Ngorika           True  GeoData Consultants Ltd
#
#        ... water_quality quality_group      quantity quantity_group  \
# id     ...
# 69572  ...          soft          good        enough         enough
# 8776   ...          soft          good  insufficient   insufficient
# 34310  ...          soft          good        enough         enough
#
#                      source           source_type source_class  \
# ...

# %%
df_categorical.isnull().sum()
# Out:
# funder                   3635
# installer                3655
# wpt_name                    0
# basin                       0
# subvillage                371
# region                      0
# lga                         0
# ward                        0
# public_meeting           3334
# recorded_by                 0
# scheme_management        3877
# permit                   3056
# extraction_type             0
# extraction_type_group       0
# extraction_type_class       0
# management                  0
# management_group            0
# payment                     0
# payment_type                0
# water_quality               0
# quality_group               0
# quantity                    0
# quantity_group              0
# source                      0
# source_type                 0
# source_class                0
# waterpoint_type             0
# waterpoint_type_group       0
# status_group                0
# dtype: int64

# %%
df_cat_fillna = df_categorical.fillna('not available')

# %%
df_cat_fillna.isnull().sum()
# Out:
# funder                   0
# installer                0
# wpt_name                 0
# basin                    0
# subvillage               0
# region                   0
# lga                      0
# ward                     0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# permit                   0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_type              0
# source_class             0
# waterpoint_type          0
# waterpoint_type_group    0
# status_group             0
# dtype: int64

# %%
df_cat_fillna.unique()
# Out:
# array(['enough', 'insufficient', 'dry', 'seasonal', 'unknown'],
#       dtype=object)

# %%
df_factorized = df_cat_fillna.apply(lambda x: pd.factorize(x)[0])
uniques
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-6e0b6dabd203> in <module>
#       1 df_factorized = df_cat_fillna.apply(lambda x: pd.factorize(x)[0])
# ----> 2 uniques
#
# NameError: name 'uniques' is not defined

# %%
df_factorized.corr()
# Out:
#                          funder  installer  wpt_name     basin  subvillage  \
# funder                 1.000000   0.567094  0.025754 -0.000964    0.026963
# installer              0.567094   1.000000  0.031976  0.008461    0.022097
# wpt_name               0.025754   0.031976  1.000000  0.000080    0.265046
# basin                 -0.000964   0.008461  0.000080  1.000000   -0.038516
# subvillage             0.026963   0.022097  0.265046 -0.038516    1.000000
# region                -0.050436  -0.042927  0.092432  0.205807   -0.034935
# lga                    0.055395   0.073809  0.009325  0.175621    0.001775
# ward                   0.091660   0.104720  0.018028 -0.071698    0.128583
# public_meeting         0.018410   0.031097  0.007305 -0.002766    0.017980
# recorded_by                 NaN        NaN       NaN       NaN         NaN
# scheme_management      0.024433   0.029852  0.017367  0.011195   -0.027368
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df_factorized.corr())

# %%
df_factorized['recorded_by'].drop
# Out:
# <bound method Series.drop of id
# 69572    0
# 8776     0
# 34310    0
# 67743    0
# 19728    0
# 9944     0
# 19816    0
# 54551    0
# 53934    0
# 46144    0
# 49056    0
# 50409    0
# 36957    0
# 50495    0
# 53752    0
# 61848    0
# 48451    0
# 58155    0
# 34169    0
# 18274    0
# 48375    0
# 6091     0
# 58500    0
# 37862    0
# 51058    0
# 22308    0
# 55012    0
# 20145    0
# 19685    0
# 69124    0
#         ..
# 14796    0
# 20387    0
# 29940    0
# 15233    0
# 49651    0
# 50998    0
# 34716    0
# 43986    0
# 38067    0
# 58255    0
# 30647    0
# 67885    0
# 47002    0
# 44616    0
# 72148    0
# 34473    0
# 34952    0
# 26640    0
# 72559    0
# 30410    0
# 13677    0
# 44885    0
# 40607    0
# 48348    0
# 11164    0
# 60739    0
# 27263    0
# 37057    0
# 31282    0
# 26348    0
# Name: recorded_by, Length: 59400, dtype: int64>

# %%
df_factorized.drop(['recorded_by'], axis = 1, inplace = True)

# %%
df_factorized.head()
# Out:
#        funder  installer  wpt_name  basin  subvillage  region  lga  ward  \
# id
# 69572       0          0         0      0           0       0    0     0
# 8776        1          1         1      1           1       1    1     1
# 34310       2          2         2      2           2       2    2     2
# 67743       3          3         3      3           3       3    3     3
# 19728       4          4         4      1           4       4    4     4
#
#        public_meeting  scheme_management  ...  water_quality  quality_group  \
# id                                        ...
# 69572               0                  0  ...              0              0
# 8776                1                  1  ...              0              0
# 34310               0                  0  ...              0              0
# 67743               0                  0  ...              0              0
# 19728               0                  2  ...              0              0
#
# ...

# %%
sns.heatmap(df_factorized.corr())

# %%
df_numeric.shape
# Out:
# (59400, 9)

# %%
df_factorized.shape
# Out:
# (59400, 28)

# %%
a = pd.concat([df_numeric, df_factorized], axis = 1)

# %%
a.head()
# Out:
#        amount_tsh  gps_height  longitude   latitude  num_private  region_code  \
# id
# 69572      6000.0        1390  34.938093  -9.856322            0           11
# 8776          0.0        1399  34.698766  -2.147466            0           20
# 34310        25.0         686  37.460664  -3.821329            0           21
# 67743         0.0         263  38.486161 -11.155298            0           90
# 19728         0.0           0  31.130847  -1.825359            0           18
#
#        district_code  population  construction_year  funder  ...  \
# id                                                           ...
# 69572              5         109               1999       0  ...
# 8776               2         280               2010       1  ...
# 34310              4         250               2009       2  ...
# 67743             63          58               1986       3  ...
# 19728              1           0                  0       4  ...
#
# ...

# %%
df_factorized.tail()
# Out:
#        funder  installer  wpt_name  basin  subvillage  region  lga  ward  \
# id
# 60739      58         49     37396      2       13171      10   63   650
# 27263     422       1035     37397      7        2780       0   15   640
# 37057      25         19        87      7       15308      17   44   449
# 31282     639        490     37398      7         452      15   23  1330
# 26348      68         61     37399      6       19287      19   49   858
#
#        public_meeting  recorded_by  ...  water_quality  quality_group  \
# id                                  ...
# 60739               0            0  ...              0              0
# 27263               0            0  ...              0              0
# 37057               0            0  ...              4              4
# 31282               0            0  ...              0              0
# 26348               0            0  ...              1              1
#
# ...

# %%
df_factorized.columns.unique
# Out:
# <bound method Index.unique of Index(['funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region',
#        'lga', 'ward', 'public_meeting', 'recorded_by', 'scheme_management',
#        'permit', 'extraction_type', 'extraction_type_group',
#        'extraction_type_class', 'management', 'management_group', 'payment',
#        'payment_type', 'water_quality', 'quality_group', 'quantity',
#        'quantity_group', 'source', 'source_type', 'source_class',
#        'waterpoint_type', 'waterpoint_type_group', 'status_group'],
#       dtype='object')>

# %%
sns.heatmap(a.corr())

# %%
a.corr()
# Out:
#                        amount_tsh  gps_height  longitude  latitude  \
# amount_tsh               1.000000    0.076650   0.022134 -0.052670
# gps_height               0.076650    1.000000   0.149155 -0.035751
# longitude                0.022134    0.149155   1.000000 -0.425802
# latitude                -0.052670   -0.035751  -0.425802  1.000000
# num_private              0.002944    0.007237   0.023873  0.006837
# region_code             -0.026813   -0.183521   0.034197 -0.221018
# district_code           -0.023599   -0.171233   0.151398 -0.201020
# population               0.016288    0.135003   0.086590 -0.022152
# construction_year        0.067915    0.658727   0.396732 -0.245278
# funder                   0.010975    0.023640   0.037756  0.049795
# installer                0.002621    0.018753   0.056257  0.037653
# wpt_name                -0.016405   -0.067008   0.043581  0.043007
# basin                    0.037596    0.014797   0.182998 -0.329994
# ...

# %%
a.tail()
# Out:
#        amount_tsh  gps_height  longitude  latitude  num_private  region_code  \
# id
# 60739        10.0        1210  37.169807 -3.253847            0            3
# 27263      4700.0        1212  35.249991 -9.070629            0           11
# 37057         0.0           0  34.017087 -8.750434            0           12
# 31282         0.0           0  35.861315 -6.378573            0            1
# 26348         0.0         191  38.104048 -6.747464            0            5
#
#        district_code  population  construction_year  funder  ...  \
# id                                                           ...
# 60739              5         125               1999      58  ...
# 27263              4          56               1996     422  ...
# 37057              7           0                  0      25  ...
# 31282              4           0                  0     639  ...
# 26348              2         150               2002      68  ...
#
# ...

# %%
a.shape
# Out:
# (59400, 37)

# %%
a.columns.unique()
# Out:
# Index(['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private',
#        'region_code', 'district_code', 'population', 'construction_year',
#        'funder', 'installer', 'wpt_name', 'basin', 'subvillage', 'region',
#        'lga', 'ward', 'public_meeting', 'scheme_management', 'permit',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group', 'status_group'],
#       dtype='object')

# %%
from sklearn.datasets import make_moons
from sklearn.linear_model import LogisticRegression

# %%
X = a[['quality_group', 'region', 'extraction_type_class', 'amount_tsh', 'longitude', 'funder', ]]
y = a.loc[:, 'status_group']

# %%
X.shape, y.shape
# Out:
# ((59400, 7), (59400,))

# %%
m = LogisticRegression(C=1e5, solver = 'lbfgs') # C is a hyperparameter (regularization, W03)
m.fit(X, y) # find the best model parameters for this data
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='lbfgs', tol=0.0001, verbose=0, warm_start=False)

# %%
print(m.score(X,y))
# Out:
# 0.5868518518518518
