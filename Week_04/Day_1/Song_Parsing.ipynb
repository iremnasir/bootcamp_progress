# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import pickle
import json

# %%
with open('PJ_songlist.txt') as f:
    song_http = [line.split(',') for line in f]

# %%
len(song_http)
# Out:
# 1

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-13-35020923e43b> in <module>
#       1 for link in song_http:
# ----> 2     pj = requests.get(link)
#       3     parser = BeautifulSoup(pj.text, 'html.parser')
#       4     song_name = link.split('/')[3].split('.htm')[0]
#       5     lyrics = parser.find_all(attrs = {'id':'lyrics-body-text'})[0]
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
# ...
