# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel("gapminder_lifeexpectancy.xlsx", index_col=0)
sns.heatmap(df.isna())

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (201, 217)

# %% [markdown]
# ## 1. Move columns into the index and out again

# %%
    df.reset_index(inplace=True)

# %%
    df.head()
# Out:
#        Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0          Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 1              Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 2              Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# 3               Angola  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# 4  Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54  33.54
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 1  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 2  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
# 3  26.98  26.98  ...  56.2  56.7  57.1  57.6  58.1  58.5  58.8  59.2  59.6
# 4  33.54  33.54  ...  75.3  75.5  75.7  75.8  75.9  76.1  76.2  76.3  76.4
#
#     2016
# 0  52.72
# 1  78.10
# 2  76.50
# 3  60.00
# 4  76.50
#
# ...

# %%
df.head()
# Out:
#        Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0          Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 1              Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 2              Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# 3               Angola  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# 4  Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54  33.54
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 1  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 2  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
# 3  26.98  26.98  ...  56.2  56.7  57.1  57.6  58.1  58.5  58.8  59.2  59.6
# 4  33.54  33.54  ...  75.3  75.5  75.7  75.8  75.9  76.1  76.2  76.3  76.4
#
#     2016
# 0  52.72
# 1  78.10
# 2  76.50
# 3  60.00
# 4  76.50
#
# ...

# %%
df.set_index("Life expectancy", inplace= True)

# %%
df.head()
# Out:
#                       1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Afghanistan          28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Albania              35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria              28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# Angola               26.98  26.98  26.98  26.98  26.98  26.98  26.98  26.98
# Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54  33.54  33.54
#
#                       1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                    ...
# Afghanistan          28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Albania              35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria              28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
# Angola               26.98  26.98  ...  56.2  56.7  57.1  57.6  58.1  58.5
# Antigua and Barbuda  33.54  33.54  ...  75.3  75.5  75.7  75.8  75.9  76.1
#
# ...

# %% [markdown]
# ### 2. Aggregation

# %%
df.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria',
#        ...
#        'Vanuatu', 'Venezuela', 'West Bank and Gaza', 'Western Sahara',
#        'Vietnam', 'Virgin Islands (U.S.)', 'Yemen', 'Zambia', 'Zimbabwe',
#        'South Sudan'],
#       dtype='object', name='Life expectancy', length=201)

# %%
df['Initials']= df.index.str[0]

# %%
df.head(3)
# Out:
#                   1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Afghanistan      28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Albania          35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria          28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                   1808   1809  ...  2008  2009  2010  2011  2012  2013  2014  \
# Life expectancy                ...
# Afghanistan      28.13  28.12  ...  52.8  53.3  53.6  54.0  54.4  54.8  54.9
# Albania          35.40  35.40  ...  76.8  77.0  77.2  77.4  77.5  77.7  77.9
# Algeria          28.82  28.82  ...  75.5  75.7  76.0  76.1  76.2  76.3  76.3
#
#                  2015   2016  Initials
# Life expectancy
# Afghanistan      53.8  52.72         A
# Albania          78.0  78.10         A
# Algeria          76.4  76.50         A
#
# [3 rows x 218 columns]

# %%
df["Initials"].value_counts()
# Out:
# S    25
# M    20
# C    18
# B    17
# G    14
# T    11
# N    11
# A    11
# P     9
# I     8
# L     8
# E     7
# U     7
# K     5
# F     5
# H     4
# R     4
# V     4
# D     3
# J     3
# Z     2
# W     2
# Q     1
# O     1
# Y     1
# Name: Initials, dtype: int64

# %%
df.groupby("Initials")[2000].count().plot.bar()

# %%
df.groupby("Initials")[2000].mean().plot.bar()

# %%
df.groupby("Initials")[[1900, 2000]].mean().plot.bar()

# %%
df.groupby("Initials")[[1900, 2000]].mean()
# Out:
#                1900       2000
# Initials
# A         34.692727  69.816364
# B         32.484706  66.423529
# C         34.235556  65.600000
# D         37.250000  70.133333
# E         32.492857  61.114286
# F         33.816000  73.632000
# G         32.394286  67.144286
# H         33.785000  70.340000
# I         34.323750  72.837500
# J         36.033333  76.266667
# K         26.068000  64.780000
# L         36.746250  66.800000
# M         31.647500  67.665500
# N         35.229091  67.737273
# O         32.300000  75.200000
# P         32.907778  71.155556
# Q         30.800000  74.700000
# R         31.112500  65.370000
# S         32.679600  68.044000
# T         30.222727  66.890909
# U         35.654286  69.514286
# V         30.475000  71.467500
# W         33.425000  68.520000
# Y         23.390000  62.400000
# Z         33.150000  46.350000

# %%
del df["Initials"]

# %% [markdown]
# ### 3. Long vs Wide Format

# %%
df_stack  = df.stack() # Wide format
df_stack.shape
# Out:
# (43617,)

# %%
df_stack
# Out:
# Life expectancy
# Afghanistan      1800    28.21
#                  1801    28.20
#                  1802    28.19
#                  1803    28.18
#                  1804    28.17
#                          ...
# South Sudan      2012    56.00
#                  2013    56.00
#                  2014    56.10
#                  2015    56.10
#                  2016    56.10
# Length: 43617, dtype: float64

# %%
df_stack.index
# Out:
# MultiIndex([('Afghanistan', 1800),
#             ('Afghanistan', 1801),
#             ('Afghanistan', 1802),
#             ('Afghanistan', 1803),
#             ('Afghanistan', 1804),
#             ('Afghanistan', 1805),
#             ('Afghanistan', 1806),
#             ('Afghanistan', 1807),
#             ('Afghanistan', 1808),
#             ('Afghanistan', 1809),
#             ...
#             ('South Sudan', 2007),
#             ('South Sudan', 2008),
#             ('South Sudan', 2009),
#             ('South Sudan', 2010),
#             ('South Sudan', 2011),
#             ('South Sudan', 2012),
#             ('South Sudan', 2013),
#             ('South Sudan', 2014),
#             ('South Sudan', 2015),
#             ('South Sudan', 2016)],
#            names=['Life expectancy', None], length=43617)

# %%
df_stack[("Iran", 2000)]
# Out:
# 71.4

# %%
subset = df_stack.sample(1000, random_state= 42)

# %%
subset
# Out:
# Life expectancy
# Fiji                   1924    26.10
# Aruba                  1963    66.79
# West Bank and Gaza     2003    74.40
# Ethiopia               1957    32.41
# Yemen                  1844    23.39
#                                ...
# Micronesia, Fed. Sts.  1910    26.70
# Eritrea                1944    30.53
# Hong Kong, China       1949    61.21
# Nepal                  1826    32.80
# Mayotte                1857    32.50
# Length: 1000, dtype: float64

# %%
subset.unstack() #Long format
# Out:
#                     1924   1963  2003   1957   1844  1862  1901  1905   1985  \
# Life expectancy
# Fiji                26.1    NaN   NaN    NaN    NaN   NaN   NaN   NaN  63.96
# Aruba                NaN  66.79   NaN    NaN    NaN   NaN   NaN   NaN    NaN
# West Bank and Gaza   NaN    NaN  74.4    NaN    NaN   NaN   NaN   NaN    NaN
# Ethiopia             NaN    NaN   NaN  32.41    NaN   NaN   NaN   NaN    NaN
# Yemen                NaN    NaN   NaN  29.76  23.39   NaN   NaN   NaN    NaN
# ...                  ...    ...   ...    ...    ...   ...   ...   ...    ...
# Vanuatu              NaN    NaN   NaN    NaN    NaN   NaN   NaN   NaN    NaN
# Spain                NaN    NaN   NaN    NaN    NaN  29.5   NaN   NaN    NaN
# Swaziland            NaN    NaN   NaN    NaN    NaN   NaN   NaN   NaN    NaN
# Nepal                NaN    NaN   NaN    NaN    NaN   NaN   NaN   NaN    NaN
# Zimbabwe             NaN    NaN   NaN    NaN    NaN   NaN   NaN   NaN    NaN
#
# ...

# %%
subset.unstack(0)
# Out:
# Life expectancy  Fiji  Aruba  West Bank and Gaza  Ethiopia  Yemen  Libya  \
# 1924             26.1    NaN                 NaN       NaN    NaN    NaN
# 1963              NaN  66.79                 NaN       NaN    NaN    NaN
# 2003              NaN    NaN                74.4       NaN    NaN    NaN
# 1957              NaN    NaN                 NaN     32.41  29.76    NaN
# 1844              NaN    NaN                 NaN       NaN  23.39    NaN
# ...               ...    ...                 ...       ...    ...    ...
# 1964              NaN    NaN                 NaN       NaN    NaN    NaN
# 1848              NaN    NaN                 NaN       NaN    NaN    NaN
# 2006              NaN    NaN                 NaN       NaN    NaN    NaN
# 1986              NaN    NaN                 NaN       NaN    NaN    NaN
# 1959              NaN    NaN                 NaN       NaN    NaN    NaN
#
# Life expectancy  Tonga  Mali  Poland  Estonia  ...  Turkey  St. Lucia  \
# ...

# %%
data = [["Germany", 2000, 80, 1.5],
        ["Germany", 2010, 82, 1.3],
       ["Germany", 2020, 80, 1.2], 
       ["Iran", 2000, 60, 1.5],
        ["Iran", 2010, 70, 1.3],
       ["Iran", 2020, 80, 1.2]]

# %%
data = pd.DataFrame(data, columns = ["Country", "Year", "pop", "fert"])

# %%
data.set_index("Country")
# Out:
#          Year  pop  fert
# Country
# Germany  2000   80   1.5
# Germany  2010   82   1.3
# Germany  2020   80   1.2
# Iran     2000   60   1.5
# Iran     2010   70   1.3
# Iran     2020   80   1.2

# %%
data.stack()
# Out:
# 0  Country    Germany
#    Year          2000
#    pop             80
#    fert           1.5
# 1  Country    Germany
#    Year          2010
#    pop             82
#    fert           1.3
# 2  Country    Germany
#    Year          2020
#    pop             80
#    fert           1.2
# 3  Country       Iran
#    Year          2000
#    pop             60
#    fert           1.5
# 4  Country       Iran
#    Year          2010
#    pop             70
#    fert           1.3
# 5  Country       Iran
#    Year          2020
#    pop             80
#    fert           1.2
# dtype: object
