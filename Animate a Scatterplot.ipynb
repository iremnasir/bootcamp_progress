# %%
import pandas as pd
fert = pd.read_csv("gapminder_total_fertility.csv", index_col = 0 )

# %%
fert.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
life =pd.read_excel("gapminder_lifeexpectancy.xlsx", index_col=0)
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# ...

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
col_name = [int(x) for x in fert.columns]

# %%
fert.columns = col_name

# %%
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
sfert = fert.stack()
slife = life.stack()

# %%
sfert
# Out:
# Total fertility rate
# Afghanistan           1800    7.00
#                       1801    7.00
#                       1802    7.00
#                       1803    7.00
#                       1804    7.00
#                               ...
# Zimbabwe              2011    3.64
#                       2012    3.56
#                       2013    3.49
#                       2014    3.41
#                       2015    3.35
# Length: 43412, dtype: float64

# %%
slife
# Out:
# Life expectancy
# Afghanistan      1800    28.21
#                  1801    28.20
#                  1802    28.19
#                  1803    28.18
#                  1804    28.17
#                          ...
# South Sudan      2012    56.00
#                  2013    56.00
#                  2014    56.10
#                  2015    56.10
#                  2016    56.10
# Length: 43857, dtype: float64

# %%
df2 = pd.DataFrame(data = {"Fertility":sfert, "Life_expectency":slife})

# %%
df2
# Out:
#                   Fertility  Life_expectency
# Afghanistan 1800        7.0            28.21
#             1801        7.0            28.20
#             1802        7.0            28.19
#             1803        7.0            28.18
#             1804        7.0            28.17
# ...                     ...              ...
# Åland       2002        NaN            81.80
#             2003        NaN            80.63
#             2004        NaN            79.88
#             2005        NaN            80.00
#             2006        NaN            80.10
#
# [44007 rows x 2 columns]

# %%
pop = pd.read_excel("gapminder_population.xlsx", index_col=0)
pop
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %%
spop = pop.stack()
spop
# Out:
# Total population
# Afghanistan                1800    3280000.0
#                            1810    3280000.0
#                            1820    3323519.0
#                            1830    3448982.0
#                            1840    3625022.0
#                                      ...
# Sint Maarten (Dutch part)  2011      33979.0
#                            2012      35134.0
#                            2013      36442.0
#                            2014      37696.0
#                            2015      38745.0
# Length: 20176, dtype: float64

# %%
df2 = pd.DataFrame(data = {"Fertility":sfert, "Life_expectency":slife, "Population":spop})
df2
# Out:
#                   Fertility  Life_expectency  Population
# Afghanistan 1800        7.0            28.21   3280000.0
#             1801        7.0            28.20         NaN
#             1802        7.0            28.19         NaN
#             1803        7.0            28.18         NaN
#             1804        7.0            28.17         NaN
# ...                     ...              ...         ...
# Åland       2006        NaN            80.10     26923.0
#             2007        NaN              NaN     26923.0
#             2008        NaN              NaN     26923.0
#             2009        NaN              NaN     26923.0
#             2010        NaN              NaN     26923.0
#
# [47688 rows x 3 columns]

# %%
df3 = df2.stack()
df3
# Out:
# Afghanistan  1800  Fertility                7.00
#                    Life_expectency         28.21
#                    Population         3280000.00
#              1801  Fertility                7.00
#                    Life_expectency         28.20
#                                          ...
# Åland        2006  Population           26923.00
#              2007  Population           26923.00
#              2008  Population           26923.00
#              2009  Population           26923.00
#              2010  Population           26923.00
# Length: 107445, dtype: float64

# %%
df3.index
# Out:
# MultiIndex([('Afghanistan', 1800,       'Fertility'),
#             ('Afghanistan', 1800, 'Life_expectency'),
#             ('Afghanistan', 1800,      'Population'),
#             ('Afghanistan', 1801,       'Fertility'),
#             ('Afghanistan', 1801, 'Life_expectency'),
#             ('Afghanistan', 1802,       'Fertility'),
#             ('Afghanistan', 1802, 'Life_expectency'),
#             ('Afghanistan', 1803,       'Fertility'),
#             ('Afghanistan', 1803, 'Life_expectency'),
#             ('Afghanistan', 1804,       'Fertility'),
#             ...
#             (      'Åland', 2004, 'Life_expectency'),
#             (      'Åland', 2004,      'Population'),
#             (      'Åland', 2005, 'Life_expectency'),
#             (      'Åland', 2005,      'Population'),
#             (      'Åland', 2006, 'Life_expectency'),
#             (      'Åland', 2006,      'Population'),
#             (      'Åland', 2007,      'Population'),
# ...

# %%
df4 = df3.unstack((0,2))

# %%
df4
# Out:
#      Afghanistan                             Akrotiri and Dhekelia   Albania  \
#        Fertility Life_expectency  Population            Population Fertility
# 1800        7.00           28.21   3280000.0                   NaN      4.60
# 1801        7.00           28.20         NaN                   NaN      4.60
# 1802        7.00           28.19         NaN                   NaN      4.60
# 1803        7.00           28.18         NaN                   NaN      4.60
# 1804        7.00           28.17         NaN                   NaN      4.60
# ...          ...             ...         ...                   ...       ...
# 2012        5.14           54.40  29726803.0                   NaN      1.76
# 2013        4.90           54.80  30682500.0                   NaN      1.77
# 2014        4.68           54.90  31627506.0                   NaN      1.78
# 2015        4.47           53.80  32526562.0                   NaN      1.78
# ...

# %%
import matplotlib.pyplot as plt

# %%
df4[["Germany", "Iran", "Spain"]].plot()

# %%
df5 = df3.unstack(2)
df5.plot.scatter('Fertility', 'Life_expectency', s=0.1)

# %%
df5
# Out:
#                   Fertility  Life_expectency  Population
# Afghanistan 1800        7.0            28.21   3280000.0
#             1801        7.0            28.20         NaN
#             1802        7.0            28.19         NaN
#             1803        7.0            28.18         NaN
#             1804        7.0            28.17         NaN
# ...                     ...              ...         ...
# Åland       2006        NaN            80.10     26923.0
#             2007        NaN              NaN     26923.0
#             2008        NaN              NaN     26923.0
#             2009        NaN              NaN     26923.0
#             2010        NaN              NaN     26923.0
#
# [47688 rows x 3 columns]

# %%
df3.index
# Out:
# MultiIndex([('Afghanistan', 1800,       'Fertility'),
#             ('Afghanistan', 1800, 'Life_expectency'),
#             ('Afghanistan', 1800,      'Population'),
#             ('Afghanistan', 1801,       'Fertility'),
#             ('Afghanistan', 1801, 'Life_expectency'),
#             ('Afghanistan', 1802,       'Fertility'),
#             ('Afghanistan', 1802, 'Life_expectency'),
#             ('Afghanistan', 1803,       'Fertility'),
#             ('Afghanistan', 1803, 'Life_expectency'),
#             ('Afghanistan', 1804,       'Fertility'),
#             ...
#             (      'Åland', 2004, 'Life_expectency'),
#             (      'Åland', 2004,      'Population'),
#             (      'Åland', 2005, 'Life_expectency'),
#             (      'Åland', 2005,      'Population'),
#             (      'Åland', 2006, 'Life_expectency'),
#             (      'Åland', 2006,      'Population'),
#             (      'Åland', 2007,      'Population'),
# ...

# %%
df6 = df3.unstack(1)
df6
# Out:
#                                              1800   1801   1802   1803   1804  \
# Afghanistan           Fertility              7.00   7.00   7.00   7.00   7.00
#                       Life_expectency       28.21  28.20  28.19  28.18  28.17
#                       Population       3280000.00    NaN    NaN    NaN    NaN
# Akrotiri and Dhekelia Population              NaN    NaN    NaN    NaN    NaN
# Albania               Fertility              4.60   4.60   4.60   4.60   4.60
# ...                                           ...    ...    ...    ...    ...
# Zimbabwe              Fertility              6.75   6.75   6.75   6.75   6.75
#                       Life_expectency       33.70  33.70  33.70  33.70  33.70
#                       Population       1085814.00    NaN    NaN    NaN    NaN
# Åland                 Life_expectency         NaN    NaN    NaN    NaN    NaN
#                       Population              NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
df7 = df6[1950]

df7
# Out:
# Afghanistan            Fertility                7.67
#                        Life_expectency         26.85
#                        Population         7752118.00
# Akrotiri and Dhekelia  Population           10661.00
# Albania                Fertility                5.80
#                                              ...
# Zimbabwe               Fertility                6.75
#                        Life_expectency         48.46
#                        Population         2746854.00
# Åland                  Life_expectency           NaN
#                        Population           21649.00
# Name: 1950, Length: 667, dtype: float64

# %%
df7 = df7.unstack(1)
df7
# Out:
#                        Fertility  Life_expectency  Population
# Afghanistan                 7.67            26.85   7752118.0
# Akrotiri and Dhekelia        NaN              NaN     10661.0
# Albania                     5.80            54.48   1263171.0
# Algeria                     7.65            42.77   8872247.0
# American Samoa               NaN              NaN     18937.0
# ...                          ...              ...         ...
# Yemen                       7.27            23.51   4402320.0
# Yugoslavia                   NaN              NaN  16285527.0
# Zambia                      6.71            42.85   2316950.0
# Zimbabwe                    6.75            48.46   2746854.0
# Åland                        NaN              NaN     21649.0
#
# [256 rows x 3 columns]

# %%
df7.plot.scatter('Fertility', 'Life_expectency')

# %%
df7["Population"] = df7["Population"]/1000000

# %%
cmap = plt.get_cmap('tab20', lut = len(df7)).colors
df7.plot.scatter('Fertility', 'Life_expectency', s=df7['Population'], c=cmap)

# %%
df7.columns
# Out:
# Index(['Fertility', 'Life_expectency', 'Population'], dtype='object')

# %%
df7
# Out:
#                        Fertility  Life_expectency  Population
# Afghanistan                 7.67            26.85    7.752118
# Akrotiri and Dhekelia        NaN              NaN    0.010661
# Albania                     5.80            54.48    1.263171
# Algeria                     7.65            42.77    8.872247
# American Samoa               NaN              NaN    0.018937
# ...                          ...              ...         ...
# Yemen                       7.27            23.51    4.402320
# Yugoslavia                   NaN              NaN   16.285527
# Zambia                      6.71            42.85    2.316950
# Zimbabwe                    6.75            48.46    2.746854
# Åland                        NaN              NaN    0.021649
#
# [256 rows x 3 columns]

# %%
df6.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
df6
# Out:
#                                              1800   1801   1802   1803   1804  \
# Afghanistan           Fertility              7.00   7.00   7.00   7.00   7.00
#                       Life_expectency       28.21  28.20  28.19  28.18  28.17
#                       Population       3280000.00    NaN    NaN    NaN    NaN
# Akrotiri and Dhekelia Population              NaN    NaN    NaN    NaN    NaN
# Albania               Fertility              4.60   4.60   4.60   4.60   4.60
# ...                                           ...    ...    ...    ...    ...
# Zimbabwe              Fertility              6.75   6.75   6.75   6.75   6.75
#                       Life_expectency       33.70  33.70  33.70  33.70  33.70
#                       Population       1085814.00    NaN    NaN    NaN    NaN
# Åland                 Life_expectency         NaN    NaN    NaN    NaN    NaN
#                       Population              NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
h = df6[2000].unstack(1)
h["Fertility"]
sel_col = df6.columns
sel_col = sel_col[160:]
sel_col
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016],
#            dtype='int64')

# %%
import imageio


sel_col = df6.columns
sel_col = sel_col[160:]
for y in sel_col:
    df_new = df6[y].unstack(1)
    image = df_new.plot.scatter('Fertility', 'Life_expectency', s= df_new["Population"]/1000000, c = cmap)
    plt.title(y)
    plt.ylim(0,100)
    plt.xlim(0,10)
    plt.savefig(f"plots/{y}.png")

# %%
list_of_images = []
for y in sel_col:
    im = imageio.imread(f"plots/{y}.png")
    list_of_images.append(im)
imageio.mimsave("animated_plot.gif", list_of_images, fps = 2)
